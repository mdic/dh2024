# %%
# This script is adapted from Corpus Approaches to Language in Social Media Online Companion (Di Cristofaro 2023), https://catlism.github.io and licensed under GPLv3.
# Import modules for: working on local folders and files; regular expressions; finding files in a folder; reading JSON files;
# using BeautifulSoup; working with XML files
import os
import re
from glob import glob
import json
from bs4 import BeautifulSoup
from lxml import etree
from datetime import datetime

# %%
# Create a regular expression to capture the title of the video preceding yt-dlphttps://www.youtube.com/watch?v=8LHSY0zmrrU default naming conventions, where:
# [FILENAME].info.json = the JSON file containing the metadata details
# [FILENAME].[LL].srv3 = the XML file containing the subtitles in SRV3 format, where [LL] is the 2-letter ISO 3166-1 language code
# The regex reads 
filename_filter = re.compile(r"(.*?)\.(info.json|[A-Za-z]{1,3}\.srv3)")
# Create an empty list to store all the video titles
unique_filenames_list = []
# List all filenames present in the folder where the script resides
files = glob("*.*")

# For every single filename found in the folder, do:
for single_file in files:
    # Search for the regular expression for capturing metadata and subtitle files in the filename, and store the result
    # in the 'found_filename' variable
    found_filename = re.search(filename_filter, single_file)
    print(found_filename)
    # If the filename matches the regular expression, extract the filename without the extensions; then check if the cleaned
    # filename is present in the unique_filenames_list, and if not add it
    if found_filename is not None and found_filename[1] not in unique_filenames_list:
        unique_filenames_list.append(found_filename[1])
# Out:
# <re.Match object; span=(0, 93), match='Is GORDON RAMSAY STEAK Worth the Hype？ Honest Rev>
# <re.Match object; span=(0, 67), match='5 Must-Try Japanese Food Experiences in Tokyo [NG>
# <re.Match object; span=(0, 63), match='I tried the CRAZIEST restaurants in Japan [gX-y56>
# <re.Match object; span=(0, 50), match='Italian McDonalds is SO GOOD [N6rUuMYG3Gw].en.srv>
# <re.Match object; span=(0, 93), match='BERLIN VEGAN FOOD GUIDE ｜ the best places to get >
# <re.Match object; span=(0, 81), match="WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD R>
# <re.Match object; span=(0, 91), match='Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazi>
# <re.Match object; span=(0, 57), match='I Tried The Best Pizza In America [0w8YpBjsW6Y].i>
# <re.Match object; span=(0, 76), match="Eating at Every Underrated Celebrity Chef's Resta>
# <re.Match object; span=(0, 95), match='I found an EXTREME RESTAURANT in the Norwegian fj>
# <re.Match object; span=(0, 99), match='Eating At The BEST Reviewed INDIAN Restaurant In >
# <re.Match object; span=(0, 55), match='I Tried The Best Pizza In America [0w8YpBjsW6Y].e>
# <re.Match object; span=(0, 96), match="GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars P>
# <re.Match object; span=(0, 62), match='Brits try 3 Michelin Star French Food! [qQ2omLxum>
# <re.Match object; span=(0, 64), match="This Could Be The BEST Food We've EVER Had [fmHDo>
# <re.Match object; span=(0, 79), match='everything i ate in vienna (vegan + plant based f>
# <re.Match object; span=(0, 65), match='EEL JELLY： How do British people eat this!？ [T_Fr>
# <re.Match object; span=(0, 97), match='Eating Bizarre French Food in Paris for 24 Hours!>
# <re.Match object; span=(0, 45), match='Italy’s best fast food! [rCAX9GfdWIw].en.srv3'>
# <re.Match object; span=(0, 63), match='The BEST Restaurants To Try In Las Vegas! [OPZD0A>
# <re.Match object; span=(0, 85), match='5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sus>
# <re.Match object; span=(0, 117), match='Eating at The Hamilton Restaurant in Washington D>
# <re.Match object; span=(0, 67), match='EEL JELLY： How do British people eat this!？ [T_Fr>
# <re.Match object; span=(0, 89), match='MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTA>
# <re.Match object; span=(0, 90), match="Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et >
# <re.Match object; span=(0, 99), match='Eating Bizarre French Food in Paris for 24 Hours!>
# <re.Match object; span=(0, 70), match="Eating at the Worst-Rated Restaurant's in London >
# <re.Match object; span=(0, 83), match="Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in >
# <re.Match object; span=(0, 60), match='Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkd>
# <re.Match object; span=(0, 113), match='Huge Iranian Food Tour!! INSANE KEBABS + Cherry R>
# <re.Match object; span=(0, 120), match="Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 CO>
# <re.Match object; span=(0, 85), match="Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in >
# <re.Match object; span=(0, 74), match='#1 Chef in China cooked for us… and it was insane>
# <re.Match object; span=(0, 63), match='I tried the CRAZIEST restaurants in Japan [gX-y56>
# <re.Match object; span=(0, 98), match='LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burge>
# <re.Match object; span=(0, 68), match="Disney Park's BEST Food! ｜ Knew It AND Chew It [L>
# <re.Match object; span=(0, 83), match='5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sus>
# <re.Match object; span=(0, 119), match='Incredible Top 10 Most Popular Italy Foods ｜｜ Ita>
# <re.Match object; span=(0, 86), match='Dining at the WORLD’S NO. 1 RESTAURANT Before It >
# <re.Match object; span=(0, 93), match='TOILET Restaurant and Hello Kitty - The CRAZIEST >
# <re.Match object; span=(0, 72), match="Eating at the Worst-Rated Restaurant's in London >
# <re.Match object; span=(0, 112), match='LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak>
# <re.Match object; span=(0, 81), match="WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD R>
# <re.Match object; span=(0, 89), match='VEGAN BUDAPEST! Vegan-Friendly cafes & street foo>
# <re.Match object; span=(0, 72), match='Eating at the Worst Reviewed Restaurant in Italy >
# <re.Match object; span=(0, 53), match='Michelin Star Christmas Dinner! [T1HYuEBKPME].en.>
# <re.Match object; span=(0, 74), match="What's The Best Chain Restaurant Steak？ Taste Tes>
# <re.Match object; span=(0, 91), match="I Tried the WORLD'S #1 Sushi Restaurant in JAPAN >
# <re.Match object; span=(0, 61), match='What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw>
# <re.Match object; span=(0, 47), match='Brutal Restaurant Reviews [zDC6Qm6tc8A].en.srv3'>
# <re.Match object; span=(0, 97), match='Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sa>
# <re.Match object; span=(0, 89), match='Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazi>
# <re.Match object; span=(0, 74), match="I Took my Dad to Shanghai's Best Reviewed Restaur>
# <re.Match object; span=(0, 93), match='TOILET Restaurant and Hello Kitty - The CRAZIEST >
# <re.Match object; span=(0, 64), match="This Could Be The BEST Food We've EVER Had [fmHDo>
# <re.Match object; span=(0, 51), match='I Rated Places With 0 Reviews [ZFhA26rPNy4].en.sr>
# <re.Match object; span=(0, 68), match='$10 vs $125 Food Truck Food in Austin, Texas!! [Z>
# <re.Match object; span=(0, 73), match='Eating At A Restaurant With No Reviews (Gone Wron>
# <re.Match object; span=(0, 68), match='Who Makes The Best Chicken Fingers？ Taste Test [G>
# <re.Match object; span=(0, 66), match='The Best Restaurant in the World (literally) [cWJ>
# <re.Match object; span=(0, 58), match='Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo>
# <re.Match object; span=(0, 40), match='I LOVE INDIAN FOOD [hnj_kw6zNMw].en.srv3'>
# <re.Match object; span=(0, 88), match='Eating at Every Restaurant on a $40,000 Cruise Sh>
# <re.Match object; span=(0, 94), match='Be Our Guest Restaurant Review at Walt Disney Wor>
# <re.Match object; span=(0, 60), match='Brits try 3 Michelin Star French Food! [qQ2omLxum>
# <re.Match object; span=(0, 120), match='72 Hours Eating ITALIAN FOOD in Rome - CARBONARA >
# <re.Match object; span=(0, 92), match='Eating At SKETCHY Restaurants For 24 Hours... (Su>
# <re.Match object; span=(0, 72), match="What's The Best Chain Restaurant Steak？ Taste Tes>
# <re.Match object; span=(0, 80), match='How to make Bolognese ｜ Gennaro Contaldo ｜ Italia>
# <re.Match object; span=(0, 99), match='Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Po>
# <re.Match object; span=(0, 74), match="Eating At Gordon Ramsay's NEW Restaurant... (5 ST>
# <re.Match object; span=(0, 73), match='BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Revi>
# <re.Match object; span=(0, 80), match='How to make Bolognese ｜ Gennaro Contaldo ｜ Italia>
# <re.Match object; span=(0, 85), match="World's Most LUXURIOUS Restaurant - Le Louis XV ->
# <re.Match object; span=(0, 116), match='31 Japanese STREET FOODS Across Japan!! TOKYO Ode>
# <re.Match object; span=(0, 93), match='TOILET Restaurant and Hello Kitty - The CRAZIEST >
# <re.Match object; span=(0, 121), match='NICHE Restaurant Review- 100% GLUTEN FREE Restaur>
# <re.Match object; span=(0, 70), match="Eating at the Worst-Rated Restaurant's in London >
# <re.Match object; span=(0, 68), match='Eating At ONLY Cheap VS Expensive Food Trucks! [q>
# <re.Match object; span=(0, 96), match='Be Our Guest Restaurant Review at Walt Disney Wor>
# <re.Match object; span=(0, 84), match="A REVIEW of Asia's TOP Restaurant - Odette (3 Mic>
# <re.Match object; span=(0, 62), match='TOP Restaurants in Disney World for 2024 [vEEQD5a>
# <re.Match object; span=(0, 62), match='Brits try Michelin-Star French desserts! [_It5qop>
# <re.Match object; span=(0, 65), match='The Best Pizza In Naples ｜ Best Of The Best [7toS>
# <re.Match object; span=(0, 85), match="Gordon Ramsay's Hell's Kitchen in Las Vegas - IS >
# <re.Match object; span=(0, 70), match='We Tried the Worst Rated Restaurants in our City >
# <re.Match object; span=(0, 77), match='I ate at every Gordon Ramsay Restaurant in the Co>
# <re.Match object; span=(0, 61), match='I tested EVERY GORDON RAMSAY restaurant [o1V9ktyl>
# <re.Match object; span=(0, 91), match='MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTA>
# <re.Match object; span=(0, 61), match='What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw>
# <re.Match object; span=(0, 67), match='Eating the BEST KOREAN STREET FOOD in SEOUL [zPuL>
# <re.Match object; span=(0, 71), match="US vs Italy McDonald's ｜ Food Wars ｜ Insider Food>
# <re.Match object; span=(0, 88), match='Eating at Every Restaurant on a $40,000 Cruise Sh>
# <re.Match object; span=(0, 70), match="Disney Park's BEST Food! ｜ Knew It AND Chew It [L>
# <re.Match object; span=(0, 86), match='Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Syd>
# <re.Match object; span=(0, 52), match="I Ate The World's Best Pizza [0sCV8j0C_uY].info.j>
# <re.Match object; span=(0, 90), match="Trying NYC's BEST Reviewed Italian Food! Is L'Art>
# <re.Match object; span=(0, 89), match='Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazi>
# <re.Match object; span=(0, 60), match='Brits try the Best Pizzas in New York! [nXnB-mEzr>
# <re.Match object; span=(0, 68), match="Disney Park's BEST Food! ｜ Knew It AND Chew It [L>
# <re.Match object; span=(0, 101), match='Eating At The BEST Reviewed INDIAN Restaurant In >
# <re.Match object; span=(0, 99), match='Eating At The BEST Reviewed INDIAN Restaurant In >
# <re.Match object; span=(0, 91), match='The PERFECT Restaurant Experience - Plénitude (Ch>
# <re.Match object; span=(0, 87), match='VEGAN BUDAPEST! Vegan-Friendly cafes & street foo>
# <re.Match object; span=(0, 55), match='I Tried The Best Pizza In America [0w8YpBjsW6Y].e>
# <re.Match object; span=(0, 113), match='Huge Iranian Food Tour!! INSANE KEBABS + Cherry R>
# <re.Match object; span=(0, 99), match='Is Classic French Cuisine Still Relevant？ - 3 Mic>
# <re.Match object; span=(0, 83), match='Everything I ate in New York City (as a Vegan) ＊r>
# <re.Match object; span=(0, 111), match="Gino Cooks 'Proper Italian Food' - Chitarra Pasta>
# <re.Match object; span=(0, 88), match="Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et >
# <re.Match object; span=(0, 123), match='NICHE Restaurant Review- 100%25 GLUTEN FREE Resta>
# <re.Match object; span=(0, 65), match='The BEST Restaurants To Try In Las Vegas! [OPZD0A>
# <re.Match object; span=(0, 70), match='Eating at the Worst Reviewed Restaurant in Italy >
# <re.Match object; span=(0, 82), match="CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 19>
# <re.Match object; span=(0, 89), match='Eating At A Restaurant With No Reviews... (SHOCKI>
# <re.Match object; span=(0, 72), match='We Tried the Worst Rated Restaurants in our City >
# <re.Match object; span=(0, 96), match='Eating at the HIGHEST RATED PERSIAN RESTAURANT in>
# <re.Match object; span=(0, 40), match='I LOVE INDIAN FOOD [hnj_kw6zNMw].en.srv3'>
# <re.Match object; span=(0, 83), match='5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sus>
# <re.Match object; span=(0, 94), match='Be Our Guest Restaurant Review at Walt Disney Wor>
# <re.Match object; span=(0, 87), match="Gordon Ramsay's Hell's Kitchen in Las Vegas - IS >
# <re.Match object; span=(0, 97), match='Eating At ANGRIEST CHEF in The Worlds Restaurant >
# <re.Match object; span=(0, 96), match='Eating at the Worst-Rated Buffet I Could Find on >
# <re.Match object; span=(0, 77), match='Food Truck Face Off in Las Vegas!! Good, Bad and >
# <re.Match object; span=(0, 114), match='31 Japanese STREET FOODS Across Japan!! TOKYO Ode>
# <re.Match object; span=(0, 82), match="LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fis>
# <re.Match object; span=(0, 77), match="My honest opinion of Noma, World's Best Restauran>
# <re.Match object; span=(0, 93), match='I found an EXTREME RESTAURANT in the Norwegian fj>
# <re.Match object; span=(0, 82), match="CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 19>
# <re.Match object; span=(0, 88), match='Finding The Best Curry House In London ｜ Food Tou>
# <re.Match object; span=(0, 89), match='MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTA>
# <re.Match object; span=(0, 61), match='I tested EVERY GORDON RAMSAY restaurant [o1V9ktyl>
# <re.Match object; span=(0, 62), match='TOP Restaurants in Disney World for 2024 [vEEQD5a>
# <re.Match object; span=(0, 65), match='The Best Pizza In Naples ｜ Best Of The Best [7toS>
# <re.Match object; span=(0, 117), match='Eating at The Hamilton Restaurant in Washington D>
# <re.Match object; span=(0, 64), match='Brits try Michelin-Star French desserts! [_It5qop>
# <re.Match object; span=(0, 89), match='MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTA>
# <re.Match object; span=(0, 70), match='Who Makes The Best Chicken Fingers？ Taste Test [G>
# <re.Match object; span=(0, 62), match='Brits try the Best Pizzas in New York! [nXnB-mEzr>
# <re.Match object; span=(0, 84), match='Dining at the WORLD’S NO. 1 RESTAURANT Before It >
# <re.Match object; span=(0, 84), match='Eating at the MOST RECOMMENDED VEGAN RESTAURANT i>
# <re.Match object; span=(0, 60), match='Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkd>
# <re.Match object; span=(0, 61), match='I tested EVERY GORDON RAMSAY restaurant [o1V9ktyl>
# <re.Match object; span=(0, 61), match='We Tried A Michelin Restaurant in Italy [4MfGn8W1>
# <re.Match object; span=(0, 68), match='The Best Restaurant in the World (literally) [cWJ>
# <re.Match object; span=(0, 104), match='Italian Tries Italian Food Abroad： Pizza, Carbona>
# <re.Match object; span=(0, 55), match='I Tried The Best Pizza In America [0w8YpBjsW6Y].e>
# <re.Match object; span=(0, 77), match='Food Truck Face Off in Las Vegas!! Good, Bad and >
# <re.Match object; span=(0, 67), match='5 Must-Try Japanese Food Experiences in Tokyo [NG>
# <re.Match object; span=(0, 88), match="Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et >
# <re.Match object; span=(0, 50), match='Italian McDonalds is SO GOOD [N6rUuMYG3Gw].en.srv>
# <re.Match object; span=(0, 117), match='Incredible Top 10 Most Popular Italy Foods ｜｜ Ita>
# <re.Match object; span=(0, 83), match="I Ate At Every Celebrity Chef's Restaurant On The>
# <re.Match object; span=(0, 96), match="GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars P>
# <re.Match object; span=(0, 55), match="Is This London's BEST Restaurant？ [sRg33njusrU].e>
# <re.Match object; span=(0, 120), match="Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 CO>
# <re.Match object; span=(0, 58), match='Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo>
# <re.Match object; span=(0, 76), match="Eating At Gordon Ramsay's NEW Restaurant... (5 ST>
# <re.Match object; span=(0, 68), match='$10 vs $125 Food Truck Food in Austin, Texas!! [Z>
# <re.Match object; span=(0, 60), match='Brits try the Best Pizzas in New York! [nXnB-mEzr>
# <re.Match object; span=(0, 122), match='72 Hours Eating ITALIAN FOOD in Rome - CARBONARA >
# <re.Match object; span=(0, 96), match='LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burge>
# <re.Match object; span=(0, 60), match='Brits try the best risotto in Italy! [LFVLuFWOkgw>
# <re.Match object; span=(0, 62), match='Brits try Michelin-Star French desserts! [_It5qop>
# <re.Match object; span=(0, 91), match="I Tried the WORLD'S #1 Sushi Restaurant in JAPAN >
# <re.Match object; span=(0, 57), match="Is This London's BEST Restaurant？ [sRg33njusrU].i>
# <re.Match object; span=(0, 83), match="I Ate At Every Celebrity Chef's Restaurant On The>
# <re.Match object; span=(0, 97), match='Eating At ANGRIEST CHEF in The Worlds Restaurant >
# <re.Match object; span=(0, 102), match='Italian Tries Italian Food Abroad： Pizza, Carbona>
# <re.Match object; span=(0, 96), match='LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burge>
# <re.Match object; span=(0, 99), match='Is Classic French Cuisine Still Relevant？ - 3 Mic>
# <re.Match object; span=(0, 67), match='The Best Pizza In Naples ｜ Best Of The Best [7toS>
# <re.Match object; span=(0, 80), match='5 Best Restaurants & Bistros in Paris (Where Loca>
# <re.Match object; span=(0, 74), match="I Took my Dad to Shanghai's Best Reviewed Restaur>
# <re.Match object; span=(0, 98), match="GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars P>
# <re.Match object; span=(0, 71), match="US vs Italy McDonald's ｜ Food Wars ｜ Insider Food>
# <re.Match object; span=(0, 90), match='HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 >
# <re.Match object; span=(0, 50), match='Michelin Star Fried Chicken! [IvVQTp7QMO0].en.srv>
# <re.Match object; span=(0, 93), match='I found an EXTREME RESTAURANT in the Norwegian fj>
# <re.Match object; span=(0, 63), match='Burger bar： 33 minutes of POV service 👌😊👍 [O14bbp>
# <re.Match object; span=(0, 97), match='Eating Bizarre French Food in Paris for 24 Hours!>
# <re.Match object; span=(0, 51), match='I Rated Places With 0 Reviews [ZFhA26rPNy4].en.sr>
# <re.Match object; span=(0, 70), match='We Tried the Worst Rated Restaurants in our City >
# <re.Match object; span=(0, 91), match='Is GORDON RAMSAY STEAK Worth the Hype？ Honest Rev>
# <re.Match object; span=(0, 92), match='Eating the 430€ Menu at the WORLD’S NO. 1 RESTAUR>
# <re.Match object; span=(0, 92), match="Trying NYC's BEST Reviewed Italian Food! Is L'Art>
# <re.Match object; span=(0, 110), match='How To Cook The Perfect Italian Tomato Sauce ｜ Ma>
# <re.Match object; span=(0, 69), match="I Tested The World's Most Luxurious Restaurants [>
# <re.Match object; span=(0, 107), match='Epic London Food Tour 🇬🇧 Best Restaurants in Lond>
# <re.Match object; span=(0, 75), match='This Is One of the Smallest Restaurants in New Yo>
# <re.Match object; span=(0, 90), match='HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 >
# <re.Match object; span=(0, 63), match='I tried the CRAZIEST restaurants in Japan [gX-y56>
# <re.Match object; span=(0, 94), match='Eating At SKETCHY Restaurants For 24 Hours... (Su>
# <re.Match object; span=(0, 72), match="What's The Best Chain Restaurant Steak？ Taste Tes>
# <re.Match object; span=(0, 120), match='72 Hours Eating ITALIAN FOOD in Rome - CARBONARA >
# <re.Match object; span=(0, 88), match='Finding The Best Curry House In London ｜ Food Tou>
# <re.Match object; span=(0, 78), match="Eating at Every Underrated Celebrity Chef's Resta>
# <re.Match object; span=(0, 85), match="World's Most LUXURIOUS Restaurant - Le Louis XV ->
# <re.Match object; span=(0, 74), match="Eating At Gordon Ramsay's NEW Restaurant... (5 ST>
# <re.Match object; span=(0, 50), match="I Ate The World's Best Pizza [0sCV8j0C_uY].en.srv>
# <re.Match object; span=(0, 55), match="Is This London's BEST Restaurant？ [sRg33njusrU].e>
# <re.Match object; span=(0, 60), match="6 Italian Pasta Recipes You Can't Miss [HW2SoMJTo>
# <re.Match object; span=(0, 98), match='Italian Street Food in Naples!! SEAFOOD SPAGHETTI>
# <re.Match object; span=(0, 72), match='#1 Chef in China cooked for us… and it was insane>
# <re.Match object; span=(0, 91), match='Is GORDON RAMSAY STEAK Worth the Hype？ Honest Rev>
# <re.Match object; span=(0, 60), match='Brits try 3 Michelin Star French Food! [qQ2omLxum>
# <re.Match object; span=(0, 62), match='TOP Restaurants in Disney World for 2024 [vEEQD5a>
# <re.Match object; span=(0, 62), match='The Best Restaurants in NYC You Must Try [0FKwPYG>
# <re.Match object; span=(0, 69), match='5 Must-Try Japanese Food Experiences in Tokyo [NG>
# <re.Match object; span=(0, 93), match='I found an EXTREME RESTAURANT in the Norwegian fj>
# <re.Match object; span=(0, 64), match='The Best Restaurants in NYC You Must Try [0FKwPYG>
# <re.Match object; span=(0, 81), match='Best Coffee Shops in Paris to Visit in 2023 ｜ Par>
# <re.Match object; span=(0, 109), match='Top 3 berühmte italienische Pasta-Rezepte! Bologn>
# <re.Match object; span=(0, 77), match='I ate at every Gordon Ramsay Restaurant in the Co>
# <re.Match object; span=(0, 80), match='How to make Bolognese ｜ Gennaro Contaldo ｜ Italia>
# <re.Match object; span=(0, 92), match='Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Rev>
# <re.Match object; span=(0, 82), match="LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fis>
# <re.Match object; span=(0, 110), match='How To Cook The Perfect Italian Tomato Sauce ｜ Ma>
# <re.Match object; span=(0, 85), match="Gordon Ramsay's Hell's Kitchen in Las Vegas - IS >
# <re.Match object; span=(0, 112), match='How To Cook The Perfect Italian Tomato Sauce ｜ Ma>
# <re.Match object; span=(0, 83), match='Best Coffee Shops in Paris to Visit in 2023 ｜ Par>
# <re.Match object; span=(0, 92), match='Eating At SKETCHY Restaurants For 24 Hours... (Su>
# <re.Match object; span=(0, 77), match="My honest opinion of Noma, World's Best Restauran>
# <re.Match object; span=(0, 79), match='Food Truck Face Off in Las Vegas!! Good, Bad and >
# <re.Match object; span=(0, 73), match='Eating At A Restaurant With No Reviews (Gone Wron>
# <re.Match object; span=(0, 90), match='Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Rev>
# <re.Match object; span=(0, 70), match='Eating at the Worst Reviewed Restaurant in Italy >
# <re.Match object; span=(0, 40), match='I LOVE INDIAN FOOD [hnj_kw6zNMw].en.srv3'>
# <re.Match object; span=(0, 109), match='Top 3 berühmte italienische Pasta-Rezepte! Bologn>
# <re.Match object; span=(0, 90), match='Eating at Every Restaurant on a $40,000 Cruise Sh>
# <re.Match object; span=(0, 79), match='everything i ate in vienna (vegan + plant based f>
# <re.Match object; span=(0, 49), match='I Tested 1-Star Restaurants [VIwwE1QrsWw].en.srv3>
# <re.Match object; span=(0, 73), match="US vs Italy McDonald's ｜ Food Wars ｜ Insider Food>
# <re.Match object; span=(0, 111), match="Gino Cooks 'Proper Italian Food' - Chitarra Pasta>
# <re.Match object; span=(0, 49), match='I Tested 1-Star Restaurants [VIwwE1QrsWw].en.srv3>
# None
# <re.Match object; span=(0, 92), match='HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 >
# <re.Match object; span=(0, 60), match="6 Italian Pasta Recipes You Can't Miss [HW2SoMJTo>
# <re.Match object; span=(0, 77), match='Food Truck Face Off in Las Vegas!! Good, Bad and >
# <re.Match object; span=(0, 94), match='Be Our Guest Restaurant Review at Walt Disney Wor>
# <re.Match object; span=(0, 52), match='Italian McDonalds is SO GOOD [N6rUuMYG3Gw].info.j>
# <re.Match object; span=(0, 79), match='I ate at every Gordon Ramsay Restaurant in the Co>
# <re.Match object; span=(0, 70), match='We Tried the Worst Rated Restaurants in our City >
# <re.Match object; span=(0, 94), match='Eating at the Worst-Rated Buffet I Could Find on >
# <re.Match object; span=(0, 56), match='VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].in>
# <re.Match object; span=(0, 70), match='Eating at the Worst Reviewed Restaurant in Italy >
# <re.Match object; span=(0, 45), match='Italy’s best fast food! [rCAX9GfdWIw].en.srv3'>
# <re.Match object; span=(0, 85), match='Everything I ate in New York City (as a Vegan) ＊r>
# <re.Match object; span=(0, 84), match="CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 19>
# <re.Match object; span=(0, 62), match='The Best Restaurants in NYC You Must Try [0FKwPYG>
# <re.Match object; span=(0, 51), match='I Rated Places With 0 Reviews [ZFhA26rPNy4].en.sr>
# <re.Match object; span=(0, 91), match='BERLIN VEGAN FOOD GUIDE ｜ the best places to get >
# <re.Match object; span=(0, 67), match='5 Must-Try Japanese Food Experiences in Tokyo [NG>
# <re.Match object; span=(0, 73), match='This Is One of the Smallest Restaurants in New Yo>
# <re.Match object; span=(0, 69), match="I Tested The World's Most Luxurious Restaurants [>
# <re.Match object; span=(0, 53), match='Michelin Star Christmas Dinner! [T1HYuEBKPME].en.>
# <re.Match object; span=(0, 76), match="I Took my Dad to Shanghai's Best Reviewed Restaur>
# <re.Match object; span=(0, 105), match='Epic London Food Tour 🇬🇧 Best Restaurants in Lond>
# <re.Match object; span=(0, 86), match="Eating At Gordon Ramsay's Kitchen Nightmares Rest>
# <re.Match object; span=(0, 61), match='We Tried A Michelin Restaurant in Italy [4MfGn8W1>
# <re.Match object; span=(0, 90), match='Finding The Best Curry House In London ｜ Food Tou>
# <re.Match object; span=(0, 49), match='I Tested 1-Star Restaurants [VIwwE1QrsWw].en.srv3>
# <re.Match object; span=(0, 83), match='Everything I ate in New York City (as a Vegan) ＊r>
# <re.Match object; span=(0, 70), match='London’s Best Restaurants 2024 - Where Chefs Eat >
# <re.Match object; span=(0, 73), match='This Is One of the Smallest Restaurants in New Yo>
# <re.Match object; span=(0, 94), match='Eating at the Worst-Rated Buffet I Could Find on >
# <re.Match object; span=(0, 102), match='Italian Tries Italian Food Abroad： Pizza, Carbona>
# <re.Match object; span=(0, 79), match="My honest opinion of Noma, World's Best Restauran>
# <re.Match object; span=(0, 71), match="US vs Italy McDonald's ｜ Food Wars ｜ Insider Food>
# <re.Match object; span=(0, 74), match="I Took my Dad to Shanghai's Best Reviewed Restaur>
# <re.Match object; span=(0, 91), match="I Tried the WORLD'S #1 Sushi Restaurant in JAPAN >
# <re.Match object; span=(0, 114), match='31 Japanese STREET FOODS Across Japan!! TOKYO Ode>
# <re.Match object; span=(0, 68), match='Eating At ONLY Cheap VS Expensive Food Trucks! [q>
# <re.Match object; span=(0, 75), match='BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Revi>
# <re.Match object; span=(0, 70), match="Eating at the Worst-Rated Restaurant's in London >
# <re.Match object; span=(0, 70), match='London’s Best Restaurants 2024 - Where Chefs Eat >
# <re.Match object; span=(0, 96), match='Eating at the HIGHEST RATED PERSIAN RESTAURANT in>
# <re.Match object; span=(0, 50), match='Italian McDonalds is SO GOOD [N6rUuMYG3Gw].en.srv>
# <re.Match object; span=(0, 89), match='The PERFECT Restaurant Experience - Plénitude (Ch>
# <re.Match object; span=(0, 84), match="LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fis>
# <re.Match object; span=(0, 96), match='Eating at the HIGHEST RATED PERSIAN RESTAURANT in>
# <re.Match object; span=(0, 113), match='Huge Iranian Food Tour!! INSANE KEBABS + Cherry R>
# <re.Match object; span=(0, 81), match='Best Coffee Shops in Paris to Visit in 2023 ｜ Par>
# <re.Match object; span=(0, 50), match="I Ate The World's Best Pizza [0sCV8j0C_uY].en.srv>
# <re.Match object; span=(0, 54), match='VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].en>
# <re.Match object; span=(0, 119), match='Eating at The Hamilton Restaurant in Washington D>
# <re.Match object; span=(0, 97), match='Eating Bizarre French Food in Paris for 24 Hours!>
# <re.Match object; span=(0, 75), match='Eating At A Restaurant With No Reviews (Gone Wron>
# <re.Match object; span=(0, 68), match="Disney Park's BEST Food! ｜ Knew It AND Chew It [L>
# <re.Match object; span=(0, 58), match='Brits try the best risotto in Italy! [LFVLuFWOkgw>
# <re.Match object; span=(0, 68), match='$10 vs $125 Food Truck Food in Austin, Texas!! [Z>
# <re.Match object; span=(0, 121), match='NICHE Restaurant Review- 100% GLUTEN FREE Restaur>
# <re.Match object; span=(0, 66), match='The Best Restaurant in the World (literally) [cWJ>
# <re.Match object; span=(0, 98), match='Italian Street Food in Naples!! SEAFOOD SPAGHETTI>
# <re.Match object; span=(0, 58), match='Brits try the best risotto in Italy! [LFVLuFWOkgw>
# <re.Match object; span=(0, 72), match='#1 Chef in China cooked for us… and it was insane>
# <re.Match object; span=(0, 90), match='HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 >
# <re.Match object; span=(0, 74), match="Eating At Gordon Ramsay's NEW Restaurant... (5 ST>
# <re.Match object; span=(0, 63), match='The BEST Restaurants To Try In Las Vegas! [OPZD0A>
# <re.Match object; span=(0, 83), match='Everything I ate in New York City (as a Vegan) ＊r>
# <re.Match object; span=(0, 102), match='Italian Tries Italian Food Abroad： Pizza, Carbona>
# <re.Match object; span=(0, 61), match='We Tried A Michelin Restaurant in Italy [4MfGn8W1>
# <re.Match object; span=(0, 96), match="GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars P>
# <re.Match object; span=(0, 91), match='BERLIN VEGAN FOOD GUIDE ｜ the best places to get >
# <re.Match object; span=(0, 62), match='Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkd>
# <re.Match object; span=(0, 87), match='Barstool Pizza Review - Venezia Italian Restauran>
# <re.Match object; span=(0, 84), match='Eating at the MOST RECOMMENDED VEGAN RESTAURANT i>
# <re.Match object; span=(0, 116), match='Eating At The Best Reviewed Gordon Ramsay Restaur>
# <re.Match object; span=(0, 101), match='Is Classic French Cuisine Still Relevant？ - 3 Mic>
# <re.Match object; span=(0, 87), match='Eating At A Restaurant With No Reviews... (SHOCKI>
# <re.Match object; span=(0, 70), match='London’s Best Restaurants 2024 - Where Chefs Eat >
# <re.Match object; span=(0, 82), match="LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fis>
# <re.Match object; span=(0, 58), match='Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo>
# <re.Match object; span=(0, 87), match="World's Most LUXURIOUS Restaurant - Le Louis XV ->
# <re.Match object; span=(0, 62), match='The Best Restaurants in NYC You Must Try [0FKwPYG>
# <re.Match object; span=(0, 73), match='BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Revi>
# <re.Match object; span=(0, 60), match="6 Italian Pasta Recipes You Can't Miss [HW2SoMJTo>
# <re.Match object; span=(0, 92), match='Eating the 430€ Menu at the WORLD’S NO. 1 RESTAUR>
# <re.Match object; span=(0, 65), match='Eating the BEST KOREAN STREET FOOD in SEOUL [zPuL>
# <re.Match object; span=(0, 78), match='5 Best Restaurants & Bistros in Paris (Where Loca>
# <re.Match object; span=(0, 87), match='VEGAN BUDAPEST! Vegan-Friendly cafes & street foo>
# <re.Match object; span=(0, 72), match='London’s Best Restaurants 2024 - Where Chefs Eat >
# <re.Match object; span=(0, 101), match='Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Po>
# <re.Match object; span=(0, 93), match='Eating At The Worst Reviewed Indian Restaurant In>
# <re.Match object; span=(0, 60), match='Brits try the Best Pizzas in New York! [nXnB-mEzr>
# <re.Match object; span=(0, 63), match='Burger bar： 33 minutes of POV service 👌😊👍 [O14bbp>
# <re.Match object; span=(0, 63), match='Burger bar： 33 minutes of POV service 👌😊👍 [O14bbp>
# <re.Match object; span=(0, 87), match='Barstool Pizza Review - Venezia Italian Restauran>
# <re.Match object; span=(0, 120), match='72 Hours Eating ITALIAN FOOD in Rome - CARBONARA >
# <re.Match object; span=(0, 65), match='Eating the BEST KOREAN STREET FOOD in SEOUL [zPuL>
# <re.Match object; span=(0, 69), match="I Tested The World's Most Luxurious Restaurants [>
# <re.Match object; span=(0, 47), match='Italy’s best fast food! [rCAX9GfdWIw].info.json'>
# <re.Match object; span=(0, 94), match='Eating the 430€ Menu at the WORLD’S NO. 1 RESTAUR>
# <re.Match object; span=(0, 62), match="6 Italian Pasta Recipes You Can't Miss [HW2SoMJTo>
# <re.Match object; span=(0, 90), match='Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Rev>
# <re.Match object; span=(0, 65), match='EEL JELLY： How do British people eat this!？ [T_Fr>
# <re.Match object; span=(0, 97), match='Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sa>
# <re.Match object; span=(0, 50), match='Michelin Star Fried Chicken! [IvVQTp7QMO0].en.srv>
# <re.Match object; span=(0, 86), match='Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Syd>
# <re.Match object; span=(0, 54), match='VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].en>
# <re.Match object; span=(0, 63), match='We Tried A Michelin Restaurant in Italy [4MfGn8W1>
# <re.Match object; span=(0, 99), match='Is Classic French Cuisine Still Relevant？ - 3 Mic>
# <re.Match object; span=(0, 72), match="What's The Best Chain Restaurant Steak？ Taste Tes>
# <re.Match object; span=(0, 64), match="This Could Be The BEST Food We've EVER Had [fmHDo>
# <re.Match object; span=(0, 82), match="CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 19>
# <re.Match object; span=(0, 65), match='The Best Pizza In Naples ｜ Best Of The Best [7toS>
# <re.Match object; span=(0, 47), match='Brutal Restaurant Reviews [zDC6Qm6tc8A].en.srv3'>
# <re.Match object; span=(0, 93), match='Eating At The Worst Reviewed Indian Restaurant In>
# <re.Match object; span=(0, 62), match='Brits try Michelin-Star French desserts! [_It5qop>
# <re.Match object; span=(0, 88), match='Finding The Best Curry House In London ｜ Food Tou>
# <re.Match object; span=(0, 82), match='How to make Bolognese ｜ Gennaro Contaldo ｜ Italia>
# <re.Match object; span=(0, 52), match='Michelin Star Fried Chicken! [IvVQTp7QMO0].info.j>
# <re.Match object; span=(0, 87), match='VEGAN BUDAPEST! Vegan-Friendly cafes & street foo>
# <re.Match object; span=(0, 65), match='I tried the CRAZIEST restaurants in Japan [gX-y56>
# <re.Match object; span=(0, 114), match='31 Japanese STREET FOODS Across Japan!! TOKYO Ode>
# <re.Match object; span=(0, 72), match='#1 Chef in China cooked for us… and it was insane>
# <re.Match object; span=(0, 92), match='Eating At SKETCHY Restaurants For 24 Hours... (Su>
# <re.Match object; span=(0, 88), match="Eating At Gordon Ramsay's Kitchen Nightmares Rest>
# <re.Match object; span=(0, 113), match="Gino Cooks 'Proper Italian Food' - Chitarra Pasta>
# <re.Match object; span=(0, 68), match='Eating At ONLY Cheap VS Expensive Food Trucks! [q>
# <re.Match object; span=(0, 65), match='EEL JELLY： How do British people eat this!？ [T_Fr>
# <re.Match object; span=(0, 89), match='The PERFECT Restaurant Experience - Plénitude (Ch>
# <re.Match object; span=(0, 90), match="Trying NYC's BEST Reviewed Italian Food! Is L'Art>
# <re.Match object; span=(0, 50), match='Michelin Star Fried Chicken! [IvVQTp7QMO0].en.srv>
# <re.Match object; span=(0, 81), match='everything i ate in vienna (vegan + plant based f>
# <re.Match object; span=(0, 111), match='Top 3 berühmte italienische Pasta-Rezepte! Bologn>
# <re.Match object; span=(0, 123), match='NICHE Restaurant Review- 100% GLUTEN FREE Restaur>
# <re.Match object; span=(0, 68), match='Who Makes The Best Chicken Fingers？ Taste Test [G>
# <re.Match object; span=(0, 76), match="Eating at Every Underrated Celebrity Chef's Resta>
# <re.Match object; span=(0, 64), match='TOP Restaurants in Disney World for 2024 [vEEQD5a>
# <re.Match object; span=(0, 71), match="I Tested The World's Most Luxurious Restaurants [>
# <re.Match object; span=(0, 86), match="Eating At Gordon Ramsay's Kitchen Nightmares Rest>
# <re.Match object; span=(0, 53), match='Michelin Star Christmas Dinner! [T1HYuEBKPME].en.>
# <re.Match object; span=(0, 83), match="Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in >
# <re.Match object; span=(0, 63), match='What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw>
# <re.Match object; span=(0, 114), match='LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak>
# <re.Match object; span=(0, 78), match='5 Best Restaurants & Bistros in Paris (Where Loca>
# <re.Match object; span=(0, 122), match="Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 CO>
# <re.Match object; span=(0, 83), match='5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sus>
# <re.Match object; span=(0, 87), match='Eating At A Restaurant With No Reviews... (SHOCKI>
# <re.Match object; span=(0, 73), match='This Is One of the Smallest Restaurants in New Yo>
# <re.Match object; span=(0, 99), match='Eating At ANGRIEST CHEF in The Worlds Restaurant >
# <re.Match object; span=(0, 99), match='Eating At The BEST Reviewed INDIAN Restaurant In >
# <re.Match object; span=(0, 70), match='Eating At ONLY Cheap VS Expensive Food Trucks! [q>
# <re.Match object; span=(0, 87), match='Barstool Pizza Review - Venezia Italian Restauran>
# <re.Match object; span=(0, 95), match='TOILET Restaurant and Hello Kitty - The CRAZIEST >
# <re.Match object; span=(0, 85), match="I Ate At Every Celebrity Chef's Restaurant On The>
# <re.Match object; span=(0, 105), match='Epic London Food Tour 🇬🇧 Best Restaurants in Lond>
# <re.Match object; span=(0, 86), match="Eating At Gordon Ramsay's Kitchen Nightmares Rest>
# <re.Match object; span=(0, 88), match='Eating at Every Restaurant on a $40,000 Cruise Sh>
# <re.Match object; span=(0, 91), match='BERLIN VEGAN FOOD GUIDE ｜ the best places to get >
# <re.Match object; span=(0, 87), match='Eating At A Restaurant With No Reviews... (SHOCKI>
# <re.Match object; span=(0, 63), match='I tested EVERY GORDON RAMSAY restaurant [o1V9ktyl>
# <re.Match object; span=(0, 55), match="Is This London's BEST Restaurant？ [sRg33njusrU].e>
# <re.Match object; span=(0, 60), match='Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo>
# <re.Match object; span=(0, 54), match='VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].en>
# <re.Match object; span=(0, 85), match="Gordon Ramsay's Hell's Kitchen in Las Vegas - IS >
# <re.Match object; span=(0, 98), match='Eating at the HIGHEST RATED PERSIAN RESTAURANT in>
# <re.Match object; span=(0, 47), match='Brutal Restaurant Reviews [zDC6Qm6tc8A].en.srv3'>
# <re.Match object; span=(0, 117), match='Incredible Top 10 Most Popular Italy Foods ｜｜ Ita>
# <re.Match object; span=(0, 93), match='Eating At The Worst Reviewed Indian Restaurant In>
# <re.Match object; span=(0, 79), match='everything i ate in vienna (vegan + plant based f>
# <re.Match object; span=(0, 55), match='Michelin Star Christmas Dinner! [T1HYuEBKPME].inf>
# <re.Match object; span=(0, 89), match='Barstool Pizza Review - Venezia Italian Restauran>
# <re.Match object; span=(0, 88), match='Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Syd>
# <re.Match object; span=(0, 100), match='Italian Street Food in Naples!! SEAFOOD SPAGHETTI>
# <re.Match object; span=(0, 89), match='The PERFECT Restaurant Experience - Plénitude (Ch>
# <re.Match object; span=(0, 93), match="I Tried the WORLD'S #1 Sushi Restaurant in JAPAN >
# <re.Match object; span=(0, 60), match='Brits try 3 Michelin Star French Food! [qQ2omLxum>
# None
# <re.Match object; span=(0, 65), match='Burger bar： 33 minutes of POV service 👌😊👍 [O14bbp>
# <re.Match object; span=(0, 84), match='Dining at the WORLD’S NO. 1 RESTAURANT Before It >
# <re.Match object; span=(0, 112), match='LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak>
# <re.Match object; span=(0, 45), match='Italy’s best fast food! [rCAX9GfdWIw].en.srv3'>
# <re.Match object; span=(0, 84), match='Eating at the MOST RECOMMENDED VEGAN RESTAURANT i>
# <re.Match object; span=(0, 81), match="WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD R>
# <re.Match object; span=(0, 60), match='Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkd>
# <re.Match object; span=(0, 63), match='The BEST Restaurants To Try In Las Vegas! [OPZD0A>
# <re.Match object; span=(0, 97), match='Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sa>
# <re.Match object; span=(0, 53), match='I Rated Places With 0 Reviews [ZFhA26rPNy4].info.>
# <re.Match object; span=(0, 85), match="World's Most LUXURIOUS Restaurant - Le Louis XV ->
# <re.Match object; span=(0, 66), match="This Could Be The BEST Food We've EVER Had [fmHDo>
# <re.Match object; span=(0, 78), match='5 Best Restaurants & Bistros in Paris (Where Loca>
# <re.Match object; span=(0, 94), match='Eating at the Worst-Rated Buffet I Could Find on >
# <re.Match object; span=(0, 117), match='Eating at The Hamilton Restaurant in Washington D>
# <re.Match object; span=(0, 88), match="Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et >
# <re.Match object; span=(0, 90), match="Trying NYC's BEST Reviewed Italian Food! Is L'Art>
# <re.Match object; span=(0, 110), match='How To Cook The Perfect Italian Tomato Sauce ｜ Ma>
# <re.Match object; span=(0, 99), match='Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Po>
# <re.Match object; span=(0, 98), match='Italian Street Food in Naples!! SEAFOOD SPAGHETTI>
# <re.Match object; span=(0, 90), match='Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Rev>
# <re.Match object; span=(0, 70), match='$10 vs $125 Food Truck Food in Austin, Texas!! [Z>
# <re.Match object; span=(0, 89), match='Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazi>
# <re.Match object; span=(0, 61), match='What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw>
# <re.Match object; span=(0, 50), match="I Ate The World's Best Pizza [0sCV8j0C_uY].en.srv>
# <re.Match object; span=(0, 99), match='Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sa>
# <re.Match object; span=(0, 58), match='Brits try the best risotto in Italy! [LFVLuFWOkgw>
# <re.Match object; span=(0, 97), match='Eating At ANGRIEST CHEF in The Worlds Restaurant >
# <re.Match object; span=(0, 49), match='Brutal Restaurant Reviews [zDC6Qm6tc8A].info.json>
# <re.Match object; span=(0, 77), match='I ate at every Gordon Ramsay Restaurant in the Co>
# <re.Match object; span=(0, 83), match="WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD R>
# <re.Match object; span=(0, 73), match='BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Revi>
# <re.Match object; span=(0, 111), match="Gino Cooks 'Proper Italian Food' - Chitarra Pasta>
# <re.Match object; span=(0, 120), match="Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 CO>
# <re.Match object; span=(0, 117), match='Incredible Top 10 Most Popular Italy Foods ｜｜ Ita>
# <re.Match object; span=(0, 81), match='Best Coffee Shops in Paris to Visit in 2023 ｜ Par>
# <re.Match object; span=(0, 112), match='LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak>
# <re.Match object; span=(0, 76), match="Eating at Every Underrated Celebrity Chef's Resta>
# <re.Match object; span=(0, 99), match='Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Po>
# <re.Match object; span=(0, 51), match='I Tested 1-Star Restaurants [VIwwE1QrsWw].info.js>
# <re.Match object; span=(0, 84), match='Dining at the WORLD’S NO. 1 RESTAURANT Before It >
# <re.Match object; span=(0, 83), match="Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in >
# <re.Match object; span=(0, 95), match='Eating At The Worst Reviewed Indian Restaurant In>
# <re.Match object; span=(0, 66), match='The Best Restaurant in the World (literally) [cWJ>
# <re.Match object; span=(0, 96), match='LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burge>
# <re.Match object; span=(0, 83), match="I Ate At Every Celebrity Chef's Restaurant On The>
# <re.Match object; span=(0, 105), match='Epic London Food Tour 🇬🇧 Best Restaurants in Lond>
# <re.Match object; span=(0, 65), match='Eating the BEST KOREAN STREET FOOD in SEOUL [zPuL>
# <re.Match object; span=(0, 115), match='Huge Iranian Food Tour!! INSANE KEBABS + Cherry R>
# <re.Match object; span=(0, 91), match='Is GORDON RAMSAY STEAK Worth the Hype？ Honest Rev>
# <re.Match object; span=(0, 92), match='Eating the 430€ Menu at the WORLD’S NO. 1 RESTAUR>
# <re.Match object; span=(0, 42), match='I LOVE INDIAN FOOD [hnj_kw6zNMw].info.json'>
# <re.Match object; span=(0, 109), match='Top 3 berühmte italienische Pasta-Rezepte! Bologn>
# None
# <re.Match object; span=(0, 73), match='Eating At A Restaurant With No Reviews (Gone Wron>
# <re.Match object; span=(0, 77), match="My honest opinion of Noma, World's Best Restauran>
# <re.Match object; span=(0, 86), match='Eating at the MOST RECOMMENDED VEGAN RESTAURANT i>
# <re.Match object; span=(0, 88), match='Dining In The World’s Most Expensive Hotel Room (>
# <re.Match object; span=(0, 86), match='Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Syd>
# <re.Match object; span=(0, 68), match='Who Makes The Best Chicken Fingers？ Taste Test [G>

# %%
# For each unique filename found do:
for filename in unique_filenames_list:
    try:
        # Recreate the full filenames with extensions, and store each one of them into a single variable
        json_file = filename + ".info.json"
        srv3_file = filename + "." + "en.srv3"
        # Create the output filename using the input filename
        output_xml = srv3_file + ".xml"
        output_txt = srv3_file + ".txt"
        # Create the XML element <text>, root element of the final output
        text_tag = etree.Element("text")
    
        print(f"Processing {json_file}")
        # Open the metadata JSON file:
        metadata_file = json.loads(open(json_file, encoding="utf8").read())
        # Read the `upload_date` datapoint in the format YYYYMMDD, and split the three values
        # for the day, the month, and the year; then assign them to three separate attributes
        date = datetime.strptime(metadata_file["upload_date"], "%Y%m%d")
        text_tag.attrib["date_d"] = str(date.day)
        text_tag.attrib["date_m"] = str(date.month)
        text_tag.attrib["date_y"] = str(date.year)
        # Check if the 'like_count' metadata point is present, if not assign the value "na" to the 'like_count' attribute

    
        # Assign the attribute 'format' with a value of 'srv' to the <text> element tag
        text_tag.attrib["format"] = "srv3"

        # Add additional metadata as selected by the class:
        text_tag.attrib["age_limit"] = str(metadata_file["age_limit"])
        text_tag.attrib["comment_count"] = str(metadata_file["comment_count"] if "comment_count" in metadata_file else "na")
        text_tag.attrib["description"] = str(metadata_file["description"])
        text_tag.attrib["fulltitle"] = str(metadata_file["fulltitle"])
        text_tag.attrib["like_count"] = str(metadata_file["like_count"] if "like_count" in metadata_file else "na")
        text_tag.attrib["location"] = str(metadata_file["location"] if "location" in metadata_file else "na")
        text_tag.attrib["playlist_title"] = str(metadata_file["playlist_title"] if "playlist_title" in metadata_file else "na")
        text_tag.attrib["release_date"] = str(metadata_file["release_date"] if "release_date" in metadata_file else "na")
        text_tag.attrib["upload_date"] = str(metadata_file["upload_date"])
        text_tag.attrib["repost_count"] = str(metadata_file["repost_count"] if "repost_count" in metadata_file else "na")
        tags = ""
        for t in metadata_file["tags"]:
            tags += f"{t}; "
        text_tag.attrib["tags"] = tags
        text_tag.attrib["title"] = str(metadata_file["title"])
        text_tag.attrib["uploader"] = str(metadata_file["uploader"])
        text_tag.attrib["view_count"] = str(metadata_file["view_count"])
        text_tag.attrib["webpage_url"] = str(metadata_file["webpage_url"])
        
        
        
                    
        print(f"Processing {srv3_file}")
        # Open the SRV3 file
        f = open(srv3_file, "r", encoding="utf8")
        # Parse its XML contents using BeautifulSoup
        soup = BeautifulSoup(f, features="xml")
        # If the attribute 'ac' (= autocaption) with value '255' is found in the <s> element tag then the subtitles are the result of autocaptioning;
        # hence assign the value 'true' to the variable 'is_ac'. Otherwise assign the value 'false' to 'is_ac'
        if soup.body.find("s", attrs={"ac": True}):
            is_ac = "true"
        else:
            is_ac = "false"
    
        # Assign the value of 'is_ac' to the <text> element tag attribute 'autocaption'
        text_tag.attrib["autocaption"] = is_ac
    
        # Create an empty list to store all the subtitles sentences to be later saved to a "plain-text" file
        plain_text = []
    
        # For each paragraph (i.e. each line of the subtitles) in the file do:
        for sent in soup.body.find_all("p"):
            # Check if the textual content of the paragraph is longer than 1 character; this avoids adding empty paragraphs to the final output
            if len(sent.get_text()) > 1:
                # Create a <p> element tag inside the XML output
                p_tag = etree.SubElement(text_tag, "p")
                # Add the attribute 'time' (indicating the starting time of the paragraph) and assign it the value appearing in 't'
                p_tag.attrib["time"] = str(sent["t"])
                # Add the attribute 'is_ac' and assign it the value of the previously created variable 'is_ac'
                p_tag.attrib["is_ac"] = is_ac
                p_tag.text = sent.get_text()
                plain_text.append(sent.get_text())
            # If the paragraph does not contain any text (i.e. its length is < 1), skip it
            else:
                continue
    
        # Write the extracted data formatted in XML to the final XML structure
        tree = etree.ElementTree(text_tag)
        # Write the XML to the output file
        tree.write(
            output_xml, pretty_print=True, xml_declaration=True, encoding="utf-8"
        )
        
        # Write the subtitles sentences only to a plain text file, one sentence per line
        with open(output_txt, "w", encoding="utf8") as o:
        # Merge together all the sentences collected in the 'plain_text' list using a new line ("\n")
            txt_contents = "\n".join(plain_text)
        # Write the merged sentences to the final .txt file
            o.write(txt_contents)
    except FileNotFoundError:
        print(f"FILE NOT FOUND for {json_file} and {srv3_file}")
# Out:
# Processing Is GORDON RAMSAY STEAK Worth the Hype？ Honest Review in Atlantic City [KSzJujp3P2A].info.json
# Processing Is GORDON RAMSAY STEAK Worth the Hype？ Honest Review in Atlantic City [KSzJujp3P2A].en.srv3
# Processing 5 Must-Try Japanese Food Experiences in Tokyo [NGxcr_Z8Dmw].info.json
# Processing 5 Must-Try Japanese Food Experiences in Tokyo [NGxcr_Z8Dmw].en.srv3
# Processing I tried the CRAZIEST restaurants in Japan [gX-y56Jd82U].info.json
# Processing I tried the CRAZIEST restaurants in Japan [gX-y56Jd82U].en.srv3
# Processing Italian McDonalds is SO GOOD [N6rUuMYG3Gw].info.json
# Processing Italian McDonalds is SO GOOD [N6rUuMYG3Gw].en.srv3
# Processing BERLIN VEGAN FOOD GUIDE ｜ the best places to get vegan food in Berlin [XMafUmR6HSw].info.json
# Processing BERLIN VEGAN FOOD GUIDE ｜ the best places to get vegan food in Berlin [XMafUmR6HSw].en.srv3
# Processing WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD REVIEW CLUB [kB_9QxytSDI].info.json
# Processing WE REVIEW CONOR MCGREGOR'S PUB IN DUBLIN ｜ FOOD REVIEW CLUB [kB_9QxytSDI].en.srv3
# Processing Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazing OR Overpriced!？ [TKg0KmZ6JY0].info.json
# Processing Eating 3 Celebrity Burgers in Las Vegas!! 🍔 Amazing OR Overpriced!？ [TKg0KmZ6JY0].en.srv3
# Processing I Tried The Best Pizza In America [0w8YpBjsW6Y].info.json
# Processing I Tried The Best Pizza In America [0w8YpBjsW6Y].en.srv3
# Processing Eating at Every Underrated Celebrity Chef's Restaurant [llU28m2_hPU].info.json
# Processing Eating at Every Underrated Celebrity Chef's Restaurant [llU28m2_hPU].en.srv3
# Processing I found an EXTREME RESTAURANT in the Norwegian fjords - Iris Restaurant [gh1iVEDisD0].info.json
# Processing I found an EXTREME RESTAURANT in the Norwegian fjords - Iris Restaurant [gh1iVEDisD0].en.srv3
# Processing Eating At The BEST Reviewed INDIAN Restaurant In Los Angeles... (5 STARS WOW) [fURUiv1o4Ww].info.json
# Processing Eating At The BEST Reviewed INDIAN Restaurant In Los Angeles... (5 STARS WOW) [fURUiv1o4Ww].en.srv3
# Processing GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars Palace｜ Best Food in Vegas [PHAefdFDI4o].info.json
# Processing GORDON RAMSAY HELL'S KITCHEN Las Vegas~ Caesars Palace｜ Best Food in Vegas [PHAefdFDI4o].en.srv3
# Processing Brits try 3 Michelin Star French Food! [qQ2omLxumtw].info.json
# Processing Brits try 3 Michelin Star French Food! [qQ2omLxumtw].en.srv3
# Processing This Could Be The BEST Food We've EVER Had [fmHDoQAngOE].info.json
# Processing This Could Be The BEST Food We've EVER Had [fmHDoQAngOE].en.srv3
# Processing everything i ate in vienna (vegan + plant based friendly) [Dh2YCicxe5E].info.json
# Processing everything i ate in vienna (vegan + plant based friendly) [Dh2YCicxe5E].en.srv3
# Processing EEL JELLY： How do British people eat this!？ [T_FrtmJ1f1E].info.json
# Processing EEL JELLY： How do British people eat this!？ [T_FrtmJ1f1E].en.srv3
# Processing Eating Bizarre French Food in Paris for 24 Hours!! Exotic Meats of Europe!! [te60IvK_vzQ].info.json
# Processing Eating Bizarre French Food in Paris for 24 Hours!! Exotic Meats of Europe!! [te60IvK_vzQ].en.srv3
# Processing Italy’s best fast food! [rCAX9GfdWIw].info.json
# Processing Italy’s best fast food! [rCAX9GfdWIw].en.srv3
# Processing The BEST Restaurants To Try In Las Vegas! [OPZD0AnnZ5w].info.json
# Processing The BEST Restaurants To Try In Las Vegas! [OPZD0AnnZ5w].en.srv3
# Processing 5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sushi and More! [Imq2hYnqkAM].info.json
# Processing 5 Must-Try Vegan Spots in Tokyo! Vegan Ramen, Sushi and More! [Imq2hYnqkAM].en.srv3
# Processing Eating at The Hamilton Restaurant in Washington DC ｜ Our Review of Restaurants in Washington DC [kYTU69uEtQE].info.json
# Processing Eating at The Hamilton Restaurant in Washington DC ｜ Our Review of Restaurants in Washington DC [kYTU69uEtQE].en.srv3
# Processing MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTAS, CHURROS & MORE! [a1Ph22n5zJs].info.json
# Processing MEXICO CITY VEGAN FOOD TOUR ｜ VEGAN, TACOS, TORTAS, CHURROS & MORE! [a1Ph22n5zJs].en.srv3
# Processing Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et Steakhouse Review [BJrjN2Sffqo].info.json
# Processing Is Salt Bae's Steakhouse a TOURIST TRAP？ Nusr-Et Steakhouse Review [BJrjN2Sffqo].en.srv3
# Processing Eating at the Worst-Rated Restaurant's in London [mPGnHWxrdB0].info.json
# Processing Eating at the Worst-Rated Restaurant's in London [mPGnHWxrdB0].en.srv3
# Processing Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in JAMES BOND!) [1yVbwEfaIXc].info.json
# Processing Reviewing LONDON'S OLDEST RESTAURANT! (Filmed in JAMES BOND!) [1yVbwEfaIXc].en.srv3
# Processing Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkdls].info.json
# Processing Eating in Italy： What to Expect 🍝🍷🍽️🇮🇹 [3uVXZHlkdls].en.srv3
# Processing Huge Iranian Food Tour!! INSANE KEBABS + Cherry Rice!! ｜ Best Persian Food in Los Angeles!! [ffkyFz39N00].info.json
# Processing Huge Iranian Food Tour!! INSANE KEBABS + Cherry Rice!! ｜ Best Persian Food in Los Angeles!! [ffkyFz39N00].en.srv3
# Processing Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 COURSE EPIC Japanese Kaiseki Dinner with Phil Tzeng [j1k1WRbWeYM].info.json
# Processing Las Vegas's #1 BEST A5 Wagyu Shabu Hotpot & 15 COURSE EPIC Japanese Kaiseki Dinner with Phil Tzeng [j1k1WRbWeYM].en.srv3
# Processing #1 Chef in China cooked for us… and it was insane. [qcnm0qMujE0].info.json
# Processing #1 Chef in China cooked for us… and it was insane. [qcnm0qMujE0].en.srv3
# Processing LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burger at the Planet Hollywood [pvO72j0_q98].info.json
# Processing LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay Burger at the Planet Hollywood [pvO72j0_q98].en.srv3
# Processing Disney Park's BEST Food! ｜ Knew It AND Chew It [Lnn0p83fPbI].info.json
# Processing Disney Park's BEST Food! ｜ Knew It AND Chew It [Lnn0p83fPbI].en.srv3
# Processing Incredible Top 10 Most Popular Italy Foods ｜｜ Italy Street Foods ｜｜ Traditional Italian Cuisine [60emxG2n8Jg].info.json
# Processing Incredible Top 10 Most Popular Italy Foods ｜｜ Italy Street Foods ｜｜ Traditional Italian Cuisine [60emxG2n8Jg].en.srv3
# Processing Dining at the WORLD’S NO. 1 RESTAURANT Before It Closes - NOMA [6s754Nn3HZY].info.json
# Processing Dining at the WORLD’S NO. 1 RESTAURANT Before It Closes - NOMA [6s754Nn3HZY].en.srv3
# Processing TOILET Restaurant and Hello Kitty - The CRAZIEST Restaurants in Taiwan! [u8oit_p5kTw].info.json
# Processing TOILET Restaurant and Hello Kitty - The CRAZIEST Restaurants in Taiwan! [u8oit_p5kTw].en.srv3
# Processing LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak at the Paris Las Vegas Resort and Casino [VyYAEKph0xM].info.json
# Processing LAS VEGAS RESTAURANT REVIEW - Gordon Ramsay Steak at the Paris Las Vegas Resort and Casino [VyYAEKph0xM].en.srv3
# Processing VEGAN BUDAPEST! Vegan-Friendly cafes & street food ｜ VEGAN TRAVEL [1Lg7OUy3Ge4].info.json
# Processing VEGAN BUDAPEST! Vegan-Friendly cafes & street food ｜ VEGAN TRAVEL [1Lg7OUy3Ge4].en.srv3
# Processing Eating at the Worst Reviewed Restaurant in Italy [LYZE7tn0oCo].info.json
# Processing Eating at the Worst Reviewed Restaurant in Italy [LYZE7tn0oCo].en.srv3
# Processing Michelin Star Christmas Dinner! [T1HYuEBKPME].info.json
# Processing Michelin Star Christmas Dinner! [T1HYuEBKPME].en.srv3
# Processing What's The Best Chain Restaurant Steak？ Taste Test [npC5RTV7uBw].info.json
# Processing What's The Best Chain Restaurant Steak？ Taste Test [npC5RTV7uBw].en.srv3
# Processing I Tried the WORLD'S #1 Sushi Restaurant in JAPAN (Impossible to Book) [HDav7oL5qNQ].info.json
# Processing I Tried the WORLD'S #1 Sushi Restaurant in JAPAN (Impossible to Book) [HDav7oL5qNQ].en.srv3
# Processing What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw3Ro].info.json
# Processing What I ate in ROME, ITALY 🇮🇹 as a VEGAN [6YzeoXmw3Ro].en.srv3
# Processing Brutal Restaurant Reviews [zDC6Qm6tc8A].info.json
# Processing Brutal Restaurant Reviews [zDC6Qm6tc8A].en.srv3
# Processing Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sandwich - Florence, Italy!! [UIct1iwOqEY].info.json
# Processing Italian Street Food!! 🥪 🇮🇹 World’s Most Famous Sandwich - Florence, Italy!! [UIct1iwOqEY].en.srv3
# Processing I Took my Dad to Shanghai's Best Reviewed Restaurant [wyPVZxkSQyE].info.json
# Processing I Took my Dad to Shanghai's Best Reviewed Restaurant [wyPVZxkSQyE].en.srv3
# Processing I Rated Places With 0 Reviews [ZFhA26rPNy4].info.json
# Processing I Rated Places With 0 Reviews [ZFhA26rPNy4].en.srv3
# Processing $10 vs $125 Food Truck Food in Austin, Texas!! [Zlzi7tsrrh4].info.json
# Processing $10 vs $125 Food Truck Food in Austin, Texas!! [Zlzi7tsrrh4].en.srv3
# Processing Eating At A Restaurant With No Reviews (Gone Wrong) [Kskry6pC1YA].info.json
# Processing Eating At A Restaurant With No Reviews (Gone Wrong) [Kskry6pC1YA].en.srv3
# Processing Who Makes The Best Chicken Fingers？ Taste Test [G3DsWnEDqbc].info.json
# Processing Who Makes The Best Chicken Fingers？ Taste Test [G3DsWnEDqbc].en.srv3
# Processing The Best Restaurant in the World (literally) [cWJ9KYqWVqY].info.json
# Processing The Best Restaurant in the World (literally) [cWJ9KYqWVqY].en.srv3
# Processing Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo].info.json
# Processing Eating A $3,000 Michelin Star Dinner [NiT7PBiEooo].en.srv3
# Processing I LOVE INDIAN FOOD [hnj_kw6zNMw].info.json
# Processing I LOVE INDIAN FOOD [hnj_kw6zNMw].en.srv3
# Processing Eating at Every Restaurant on a $40,000 Cruise Ship!! (Antarctica) [aAgwG5PKzdM].info.json
# Processing Eating at Every Restaurant on a $40,000 Cruise Ship!! (Antarctica) [aAgwG5PKzdM].en.srv3
# Processing Be Our Guest Restaurant Review at Walt Disney World ｜ Disney Dining Show [pumR7TbLU44].info.json
# Processing Be Our Guest Restaurant Review at Walt Disney World ｜ Disney Dining Show [pumR7TbLU44].en.srv3
# Processing 72 Hours Eating ITALIAN FOOD in Rome - CARBONARA + PIZZA - Italian street food tour in Rome, Italy [dI-5IBE_vIs].info.json
# Processing 72 Hours Eating ITALIAN FOOD in Rome - CARBONARA + PIZZA - Italian street food tour in Rome, Italy [dI-5IBE_vIs].en.srv3
# Processing Eating At SKETCHY Restaurants For 24 Hours... (Surprisingly Delicious) [kxXqKZzAubA].info.json
# Processing Eating At SKETCHY Restaurants For 24 Hours... (Surprisingly Delicious) [kxXqKZzAubA].en.srv3
# Processing How to make Bolognese ｜ Gennaro Contaldo ｜ Italian Special [_qy6HNqxhKU].info.json
# Processing How to make Bolognese ｜ Gennaro Contaldo ｜ Italian Special [_qy6HNqxhKU].en.srv3
# Processing Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Portuguese Food Tour in Porto! [_tpr73ZAi2s].info.json
# Processing Portugal Street Food!! 🇵🇹 KING OF SANDWICHES - Portuguese Food Tour in Porto! [_tpr73ZAi2s].en.srv3
# Processing Eating At Gordon Ramsay's NEW Restaurant... (5 STAR) [4a8eDnQd7JY].info.json
# Processing Eating At Gordon Ramsay's NEW Restaurant... (5 STAR) [4a8eDnQd7JY].en.srv3
# Processing BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Review [AKIrGWF1uQI].info.json
# Processing BEST FOOD IN AMSTERDAM ｜ Ultimate Vegan Food Review [AKIrGWF1uQI].en.srv3
# Processing World's Most LUXURIOUS Restaurant - Le Louis XV - Alain Ducasse [-RAmiqe2neU].info.json
# Processing World's Most LUXURIOUS Restaurant - Le Louis XV - Alain Ducasse [-RAmiqe2neU].en.srv3
# Processing 31 Japanese STREET FOODS Across Japan!! TOKYO Oden, OSAKA Sushi, KYOTO Mochi + FUKUOKA Ramen [Ib7Om8X_qZg].info.json
# Processing 31 Japanese STREET FOODS Across Japan!! TOKYO Oden, OSAKA Sushi, KYOTO Mochi + FUKUOKA Ramen [Ib7Om8X_qZg].en.srv3
# Processing NICHE Restaurant Review- 100% GLUTEN FREE Restaurant in London - Award Winning Modern Casual Dining [6N8TjOuOjHA].info.json
# Processing NICHE Restaurant Review- 100% GLUTEN FREE Restaurant in London - Award Winning Modern Casual Dining [6N8TjOuOjHA].en.srv3
# Processing Eating At ONLY Cheap VS Expensive Food Trucks! [qxkhoyXOPhc].info.json
# Processing Eating At ONLY Cheap VS Expensive Food Trucks! [qxkhoyXOPhc].en.srv3
# Processing A REVIEW of Asia's TOP Restaurant - Odette (3 Michelin Star) [LA4YlvFSxW4].info.json
# Processing A REVIEW of Asia's TOP Restaurant - Odette (3 Michelin Star) [LA4YlvFSxW4].en.srv3
# FILE NOT FOUND for A REVIEW of Asia's TOP Restaurant - Odette (3 Michelin Star) [LA4YlvFSxW4].info.json and A REVIEW of Asia's TOP Restaurant - Odette (3 Michelin Star) [LA4YlvFSxW4].en.srv3
# Processing TOP Restaurants in Disney World for 2024 [vEEQD5anSOI].info.json
# Processing TOP Restaurants in Disney World for 2024 [vEEQD5anSOI].en.srv3
# Processing Brits try Michelin-Star French desserts! [_It5qopgPZs].info.json
# Processing Brits try Michelin-Star French desserts! [_It5qopgPZs].en.srv3
# Processing The Best Pizza In Naples ｜ Best Of The Best [7toSikYGFNM].info.json
# Processing The Best Pizza In Naples ｜ Best Of The Best [7toSikYGFNM].en.srv3
# Processing Gordon Ramsay's Hell's Kitchen in Las Vegas - IS the HYPE Real？ [-p5cMPhg7eg].info.json
# Processing Gordon Ramsay's Hell's Kitchen in Las Vegas - IS the HYPE Real？ [-p5cMPhg7eg].en.srv3
# Processing We Tried the Worst Rated Restaurants in our City [f0CsMgRZDio].info.json
# Processing We Tried the Worst Rated Restaurants in our City [f0CsMgRZDio].en.srv3
# Processing I ate at every Gordon Ramsay Restaurant in the Country! [_cVBzeq16y8].info.json
# Processing I ate at every Gordon Ramsay Restaurant in the Country! [_cVBzeq16y8].en.srv3
# Processing I tested EVERY GORDON RAMSAY restaurant [o1V9ktylc7E].info.json
# Processing I tested EVERY GORDON RAMSAY restaurant [o1V9ktylc7E].en.srv3
# Processing Eating the BEST KOREAN STREET FOOD in SEOUL [zPuLGkluoTY].info.json
# Processing Eating the BEST KOREAN STREET FOOD in SEOUL [zPuLGkluoTY].en.srv3
# Processing US vs Italy McDonald's ｜ Food Wars ｜ Insider Food [S5TbHPXux9k].info.json
# Processing US vs Italy McDonald's ｜ Food Wars ｜ Insider Food [S5TbHPXux9k].en.srv3
# Processing Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Sydney, Australia! [JCfI9Xlj7Io].info.json
# Processing Australian Fast Food!! 🇦🇺 TOP 5 CHEAP EATS in Sydney, Australia! [JCfI9Xlj7Io].en.srv3
# Processing I Ate The World's Best Pizza [0sCV8j0C_uY].info.json
# Processing I Ate The World's Best Pizza [0sCV8j0C_uY].en.srv3
# Processing Trying NYC's BEST Reviewed Italian Food! Is L'Artusi Worth the Hype？ [9kraJpb59GE].info.json
# Processing Trying NYC's BEST Reviewed Italian Food! Is L'Artusi Worth the Hype？ [9kraJpb59GE].en.srv3
# Processing Brits try the Best Pizzas in New York! [nXnB-mEzrls].info.json
# Processing Brits try the Best Pizzas in New York! [nXnB-mEzrls].en.srv3
# Processing The PERFECT Restaurant Experience - Plénitude (Cheval Blanc, Paris) [mm5DIoPvkJE].info.json
# Processing The PERFECT Restaurant Experience - Plénitude (Cheval Blanc, Paris) [mm5DIoPvkJE].en.srv3
# Processing Is Classic French Cuisine Still Relevant？ - 3 Michelin Star Restaurant Review [gbbXEZbbD5M].info.json
# Processing Is Classic French Cuisine Still Relevant？ - 3 Michelin Star Restaurant Review [gbbXEZbbD5M].en.srv3
# Processing Everything I ate in New York City (as a Vegan) ＊rip my money＊ [cFDkbrBDtas].info.json
# Processing Everything I ate in New York City (as a Vegan) ＊rip my money＊ [cFDkbrBDtas].en.srv3
# Processing Gino Cooks 'Proper Italian Food' - Chitarra Pasta ｜ Gino's Italian Escape E19 ｜ Our Taste [CEKSRRAP5Uc].info.json
# Processing Gino Cooks 'Proper Italian Food' - Chitarra Pasta ｜ Gino's Italian Escape E19 ｜ Our Taste [CEKSRRAP5Uc].en.srv3
# Processing NICHE Restaurant Review- 100%25 GLUTEN FREE Restaurant in London - Award Winning Modern Casual Dining [6N8TjOuOjHA].info.json
# FILE NOT FOUND for NICHE Restaurant Review- 100%25 GLUTEN FREE Restaurant in London - Award Winning Modern Casual Dining [6N8TjOuOjHA].info.json and NICHE Restaurant Review- 100%25 GLUTEN FREE Restaurant in London - Award Winning Modern Casual Dining [6N8TjOuOjHA].en.srv3
# Processing CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 1950's Diner! [tT1obEovlPQ].info.json
# Processing CLASSIC AMERICAN DINER - WAITE PARK DINER!!! - 1950's Diner! [tT1obEovlPQ].en.srv3
# Processing Eating At A Restaurant With No Reviews... (SHOCKING New Dive Bar) [bQMVGbXRPJ4].info.json
# Processing Eating At A Restaurant With No Reviews... (SHOCKING New Dive Bar) [bQMVGbXRPJ4].en.srv3
# Processing Eating at the HIGHEST RATED PERSIAN RESTAURANT in Las Vegas (Full Review!) [3tYyMBo0mZA].info.json
# Processing Eating at the HIGHEST RATED PERSIAN RESTAURANT in Las Vegas (Full Review!) [3tYyMBo0mZA].en.srv3
# Processing Eating At ANGRIEST CHEF in The Worlds Restaurant (And I REVIEWED THE FOOD!) [8D4gqixruWw].info.json
# Processing Eating At ANGRIEST CHEF in The Worlds Restaurant (And I REVIEWED THE FOOD!) [8D4gqixruWw].en.srv3
# Processing Eating at the Worst-Rated Buffet I Could Find on Yelp ｜ One Star Reviews [fhDinQ01zTw].info.json
# Processing Eating at the Worst-Rated Buffet I Could Find on Yelp ｜ One Star Reviews [fhDinQ01zTw].en.srv3
# Processing Food Truck Face Off in Las Vegas!! Good, Bad and Ugly!! [CtCTP3pXc-k].info.json
# Processing Food Truck Face Off in Las Vegas!! Good, Bad and Ugly!! [CtCTP3pXc-k].en.srv3
# Processing LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fish and Chips [1ASClwa37og].info.json
# Processing LAS VEGAS RESTAURANT REVIEW - Gordan Ramsay's Fish and Chips [1ASClwa37og].en.srv3
# Processing My honest opinion of Noma, World's Best Restaurant 2021 [A6mZRDgluYg].info.json
# Processing My honest opinion of Noma, World's Best Restaurant 2021 [A6mZRDgluYg].en.srv3
# Processing Finding The Best Curry House In London ｜ Food Tours ｜ Food Insider [uQv_2pTxddA].info.json
# Processing Finding The Best Curry House In London ｜ Food Tours ｜ Food Insider [uQv_2pTxddA].en.srv3
# Processing Eating at the MOST RECOMMENDED VEGAN RESTAURANT in London, UK! [mYFSNyD_4_Q].info.json
# Processing Eating at the MOST RECOMMENDED VEGAN RESTAURANT in London, UK! [mYFSNyD_4_Q].en.srv3
# Processing We Tried A Michelin Restaurant in Italy [4MfGn8W17qQ].info.json
# Processing We Tried A Michelin Restaurant in Italy [4MfGn8W17qQ].en.srv3
# Processing Italian Tries Italian Food Abroad： Pizza, Carbonara and More! ｜ Easy Italian 134 [JEYUdn7zrC0].info.json
# Processing Italian Tries Italian Food Abroad： Pizza, Carbonara and More! ｜ Easy Italian 134 [JEYUdn7zrC0].en.srv3
# Processing I Ate At Every Celebrity Chef's Restaurant On The Vegas Strip [BPGgyputhpA].info.json
# Processing I Ate At Every Celebrity Chef's Restaurant On The Vegas Strip [BPGgyputhpA].en.srv3
# Processing Is This London's BEST Restaurant？ [sRg33njusrU].info.json
# Processing Is This London's BEST Restaurant？ [sRg33njusrU].en.srv3
# Processing Brits try the best risotto in Italy! [LFVLuFWOkgw].info.json
# Processing Brits try the best risotto in Italy! [LFVLuFWOkgw].en.srv3
# Processing 5 Best Restaurants & Bistros in Paris (Where Locals Eat) [Be2HlpLExcw].info.json
# Processing 5 Best Restaurants & Bistros in Paris (Where Locals Eat) [Be2HlpLExcw].en.srv3
# Processing HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 ⧸ 5 STARS REVIEWS!) [9IwpFiXljZM].info.json
# Processing HIGHEST RATED BBQ Restaurant in AMERICA! (15,000 ⧸ 5 STARS REVIEWS!) [9IwpFiXljZM].en.srv3
# Processing Michelin Star Fried Chicken! [IvVQTp7QMO0].info.json
# Processing Michelin Star Fried Chicken! [IvVQTp7QMO0].en.srv3
# Processing Burger bar： 33 minutes of POV service 👌😊👍 [O14bbpvy2x0].info.json
# Processing Burger bar： 33 minutes of POV service 👌😊👍 [O14bbpvy2x0].en.srv3
# Processing Eating the 430€ Menu at the WORLD’S NO. 1 RESTAURANT (2022) - Geranium [c2RKdhmpf8A].info.json
# Processing Eating the 430€ Menu at the WORLD’S NO. 1 RESTAURANT (2022) - Geranium [c2RKdhmpf8A].en.srv3
# Processing How To Cook The Perfect Italian Tomato Sauce ｜ MasterChef New Zealand ｜ MasterChef World [ctRo3pmFaKQ].info.json
# Processing How To Cook The Perfect Italian Tomato Sauce ｜ MasterChef New Zealand ｜ MasterChef World [ctRo3pmFaKQ].en.srv3
# Processing I Tested The World's Most Luxurious Restaurants [N7li-6TsxMo].info.json
# Processing I Tested The World's Most Luxurious Restaurants [N7li-6TsxMo].en.srv3
# Processing Epic London Food Tour 🇬🇧 Best Restaurants in London ｜ What & Where to Eat in London [qOMikKh1pEM].info.json
# Processing Epic London Food Tour 🇬🇧 Best Restaurants in London ｜ What & Where to Eat in London [qOMikKh1pEM].en.srv3
# Processing This Is One of the Smallest Restaurants in New York [uikOKrrwsfw].info.json
# Processing This Is One of the Smallest Restaurants in New York [uikOKrrwsfw].en.srv3
# Processing 6 Italian Pasta Recipes You Can't Miss [HW2SoMJToIo].info.json
# Processing 6 Italian Pasta Recipes You Can't Miss [HW2SoMJToIo].en.srv3
# Processing Italian Street Food in Naples!! SEAFOOD SPAGHETTI + Pizza in Naples, Italy!! [nV8zOhYBHP4].info.json
# Processing Italian Street Food in Naples!! SEAFOOD SPAGHETTI + Pizza in Naples, Italy!! [nV8zOhYBHP4].en.srv3
# Processing The Best Restaurants in NYC You Must Try [0FKwPYG6a0M].info.json
# Processing The Best Restaurants in NYC You Must Try [0FKwPYG6a0M].en.srv3
# Processing Best Coffee Shops in Paris to Visit in 2023 ｜ Parisian Vibe [wa9pkt-HtQo].info.json
# Processing Best Coffee Shops in Paris to Visit in 2023 ｜ Parisian Vibe [wa9pkt-HtQo].en.srv3
# Processing Top 3 berühmte italienische Pasta-Rezepte! Bolognese, Carbonara und Fettuccine Alfredo! [HrAi1R1F9Pw].info.json
# Processing Top 3 berühmte italienische Pasta-Rezepte! Bolognese, Carbonara und Fettuccine Alfredo! [HrAi1R1F9Pw].en.srv3
# Processing Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Review in Times Square [e3wxposHuPw].info.json
# Processing Is GORDON RAMSAY Fish & Chips a TOURIST TRAP？ Review in Times Square [e3wxposHuPw].en.srv3
# Processing I Tested 1-Star Restaurants [VIwwE1QrsWw].info.json
# Processing I Tested 1-Star Restaurants [VIwwE1QrsWw].en.srv3
# Processing VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].info.json
# Processing VEGAN IN PARIS ｜ best vegan eats [1_nIcdlnohg].en.srv3
# Processing Eating At Gordon Ramsay's Kitchen Nightmares Restaurant (1 STAR) [2WGS5Zzcgfk].info.json
# Processing Eating At Gordon Ramsay's Kitchen Nightmares Restaurant (1 STAR) [2WGS5Zzcgfk].en.srv3
# Processing London’s Best Restaurants 2024 - Where Chefs Eat [AMj51nd4Oeg].info.json
# Processing London’s Best Restaurants 2024 - Where Chefs Eat [AMj51nd4Oeg].en.srv3
# Processing Barstool Pizza Review - Venezia Italian Restaurant (Sarasota, FL) [LZot0TreJLY].info.json
# Processing Barstool Pizza Review - Venezia Italian Restaurant (Sarasota, FL) [LZot0TreJLY].en.srv3
# Processing Eating At The Best Reviewed Gordon Ramsay Restaurant (Las Vegas) ＊CALLING GORDON RAMSAY OUT＊ [kTRhrLYF690].info.json
# Processing Eating At The Best Reviewed Gordon Ramsay Restaurant (Las Vegas) ＊CALLING GORDON RAMSAY OUT＊ [kTRhrLYF690].en.srv3
# FILE NOT FOUND for Eating At The Best Reviewed Gordon Ramsay Restaurant (Las Vegas) ＊CALLING GORDON RAMSAY OUT＊ [kTRhrLYF690].info.json and Eating At The Best Reviewed Gordon Ramsay Restaurant (Las Vegas) ＊CALLING GORDON RAMSAY OUT＊ [kTRhrLYF690].en.srv3
# Processing Eating At The Worst Reviewed Indian Restaurant In My City (Los Angeles) [8C4WLYtvbuI].info.json
# Processing Eating At The Worst Reviewed Indian Restaurant In My City (Los Angeles) [8C4WLYtvbuI].en.srv3
# Processing Dining In The World’s Most Expensive Hotel Room ($100,000⧸night) [cfKi70A-6iY].info.json
# Processing Dining In The World’s Most Expensive Hotel Room ($100,000⧸night) [cfKi70A-6iY].en.srv3
# FILE NOT FOUND for Dining In The World’s Most Expensive Hotel Room ($100,000⧸night) [cfKi70A-6iY].info.json and Dining In The World’s Most Expensive Hotel Room ($100,000⧸night) [cfKi70A-6iY].en.srv3
